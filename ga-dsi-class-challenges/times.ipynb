# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Regression Challenge
# Week 3 | Day 5

# %% [markdown]
# ## The Times university ranking dataset analysis
#
# In this challenge, you will draw on the skills you have learned over the past three weeks to create a model of university prestige using the provided predictors. Specifically, your goal is to **predict the total score for the university for the year 2016**.
#
#
# - You will be provided with the data and targets from 2011 through 2015 and the data (no targets) for 2016.<br><br>
#
# - Before 12:00pm, all final answers should be submitted by filling in the  predicted values for each university in the submission sheet. (.to_csv() should be useful for this). <br><br>
#
# - Your submission will be assessed on MSE -- so consider your loss functions! <br><br>

# %% [markdown]
# ## The Dataset
#
# The data is in a csv file in your repo. It contains the following columns:
#
# - **world_rank** - world rank for the university. Contains rank ranges and equal ranks (e.g. = 94 and 201-250).
# - **university_name** - name of university.
# - **country** - country of each university.
# - **teaching** - university score for teaching (the learning environment).
# - **international** - university score international outlook (staff, students, research).
# - **research** - university score for research (volume, income and reputation).
# - **citations** - university score for citations (research influence).
# - **income** - university score for industry income (knowledge transfer).
# - **total_score** - total score for university, used to determine rank.
# - **num_students** - number of students at the university.
# - **student_staff_ratio** - Number of students divided by number of staff.
# - **international_students** - Percentage of students who are international.
# - **female_male_ratio** - Female student to Male student ratio.
# - **year** - year of the ranking (2011 to 2016 included).
#
# The target is the **total score**, which directly corresponds to the final ranking.
#
# **N.B. - if the total score is reported as "-" that will be considered a 0 when scoring.**

# %% [markdown]
# ## Guidelines
#
# The analysis is up to you. **This is fully open-ended.** You are expected to:
#
# - Load the packages you need to do analysis
# - Perform EDA on variables of interest
# - Form a hypothesis or hypotheses on what is important for the score
# - Check your data for problems, clean and munge data into correct formats
# - Create or combine new columns/features where beneficial
# - Perform statistical analysis with regression and describe the results
#
# ---
#
# I will be here in class to help, but if you do not know how to do something, I expect you to **check documentation first**.
#
# **You are not expected to know how to do things by heart. Knowing how to effectively look up the answers on the internet is a critical skill for data scientists!**

# %% [markdown]
# ## Teams
#
# Finally, you will be working as part of a team on this. To the randomizer...

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('datasets/challenge-dataset.csv', na_values=['-'], encoding='latin1')

# %% [raw]
# df.info()

# %% [raw]
# df.total_score.unique()

# %%
df.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# 0      99.7           72.4      98.7       98.8    34.5         96.1
# 1      97.7           54.6      98.0       99.9    83.7         96.0
# 2      97.8           82.3      91.4       99.9    87.5         95.6
# 3      98.3           29.5      98.1       99.2    64.3         94.3
# 4      90.9           70.3      95.4       99.9     NaN         94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
# 3       15,596                  7.8                    22%          42:58:00
# 4        7,929                  8.4                    27%          45:55:00
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
print ' ||'.join(df.columns.values.tolist())
# Out:
# world_rank ||university_name ||country ||teaching ||international ||research ||citations ||income ||total_score ||num_students ||student_staff_ratio ||international_students ||female_male_ratio ||year

# %%
df.dtypes
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international             float64
# research                  float64
# citations                 float64
# income                    float64
# total_score               float64
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# dtype: object

# %%
def rem_symbol(x):
    try:
        for i in [',', '%']:
            x = x.replace(i, '')
            return float(x)
    except:
        return np.nan
        print x

# %%
df['num_students'] = df['num_students'].map(rem_symbol)

# %% [raw]
# df['international_students'].unique()

# %%
df['percent_international_students'] = df['international_students'].map(lambda x: float(str(x).strip('%')))

# %%
def fm_ratio(x):
    if type(x) == float:
        return x
    try:
        return float(x)
    except:
        x = x.split(':')
        f = x[0]
        m = x[1]
        try:
            return float(f)/float(m)
        except:
            if float(f) > 0:
                return float(f)

# %%
df['female_male_ratio'] = df['female_male_ratio'].map(fm_ratio)

# %% [raw]
# df.dtypes

# %%
df.loc[df['country']=='Unisted States of America', 'country'] = 'United States of America'
df.loc[df['country']=='Unted Kingdom', 'country'] = 'United Kingdom'

# %%
country_dict = {}
count = 0
for i in df['country'].unique():
    country_dict[i] = count
    count += 1
df['country_number'] = df['country'].map(country_dict)

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.heatmap(df.corr())

# %% [markdown]
# # How Alex wanted it to be done

# %%
df3 = df.copy()

# %%
df3['to_drop'] = df3['world_rank'].map(lambda x: 'drop' if '-' in x else x)

# %%
df4 = df3[df3['to_drop']!='drop']

# %%
features = df.columns.values.tolist()[3:]
features.remove('female_male_ratio')
features.remove('international_students')

train = df4[df4['year'] != 2016]
predict = df4.copy()[df4['year'] == 2016]
train = train.copy()
train.dropna(inplace=True)
predict = predict.copy()
predict = predict.drop('total_score', axis=1)

features.remove('total_score')
X_train = train[features]
X = predict[features]
X = X.copy()
y_train = train['total_score']

# %%
X.fillna(0,inplace=True)

# %%
r2 = linear_model.RidgeCV(cv=5)
mx = r2.fit(X_train, y_train)
px = mx.predict(X)

# %%
mx.score(X_train, y_train)
# Out:
# 0.99954040074006145

# %%
px = pd.DataFrame(px, columns=['pred_score'])

# %%
predict.reset_index(drop=True, inplace=True)

# %%
final = pd.concat([predict, px], axis=1)

# %%
new_test = final[['university_name', 'pred_score']]

# %%
submit = pd.read_csv('datasets/ranking-submission.csv', encoding='latin1')

# %%
new_sub = submit.merge(new_test, how='left', on='university_name')

# %%
new_sub.drop('total_score', inplace=True, axis=1)

# %%
new_sub
# Out:
#     world_rank                                    university_name  pred_score
# 0            1                 California Institute of Technology   95.104229
# 1            2                               University of Oxford   93.953870
# 2            3                                Stanford University   93.720756
# 3            4                            University of Cambridge   92.596815
# 4            5              Massachusetts Institute of Technology   91.844535
# 5            6                                 Harvard University   91.493941
# 6            7                               Princeton University   89.918683
# 7            8                            Imperial College London   88.948360
# 8            9  ETH Zurich Ð Swiss Federal Institute of Techno...   88.024798
# 9           10                              University of Chicago   87.833692
# 10          11                           Johns Hopkins University   87.516929
# 11          12                                    Yale University   87.248140
# 12          13                 University of California, Berkeley   87.118888
# 13          14                          University College London   86.920575
# 14          15                                Columbia University   85.244155
# 15          16              University of California, Los Angeles   85.757052
# 16          17                         University of Pennsylvania   85.186589
# 17          18                                 Cornell University   83.894011
# 18          19                              University of Toronto   83.699490
# 19          20                                    Duke University   82.607409
# 20          21                             University of Michigan   82.330743
# 21          22                         Carnegie Mellon University   82.379436
# 22          23   London School of Economics and Political Science   80.764269
# 23          24                            University of Edinburgh   80.082744
# 24          25                            Northwestern University   79.443806
# 25          26                   National University of Singapore   78.864632
# 26          27                              KingÕs College London   78.047285
# 27          28                               Karolinska Institute   77.457920
# 28          29                                         LMU Munich   77.223163
# 29          30                                New York University   77.166701
# ..         ...                                                ...         ...
# 770    601-800                               University of Tehran         NaN
# 771    601-800                     University of Texas at El Paso         NaN
# 772    601-800                              Texas Tech University         NaN
# 773    601-800                                   Tokai University         NaN
# 774    601-800                               Tokushima University         NaN
# 775    601-800  Tokyo University of Marine Science and Technology         NaN
# 776    601-800                        Tokyo University of Science         NaN
# 777    601-800                             Tomsk State University         NaN
# 778    601-800                                 Tottori University         NaN
# 779    601-800                 Toyohashi University of Technology         NaN
# 780    601-800                     Universiti Kebangsaan Malaysia         NaN
# 781    601-800                          Universiti Putra Malaysia         NaN
# 782    601-800                          Universiti Sains Malaysia         NaN
# 783    601-800                          Universiti Teknologi MARA         NaN
# 784    601-800                            Ural Federal University         NaN
# 785    601-800           V.N. Karazin Kharkiv National University         NaN
# 786    601-800                                 University of Vigo         NaN
# 787    601-800                                 Vilnius University         NaN
# 788    601-800                    Warsaw University of Technology         NaN
# 789    601-800                                  Waseda University         NaN
# 790    601-800                         University of West Bohemia         NaN
# 791    601-800                  University of the West of England         NaN
# 792    601-800                       West University of Timi_oara         NaN
# 793    601-800                          University of Westminster         NaN
# 794    601-800                                  Xidian University         NaN
# 795    601-800                                Yeungnam University         NaN
# 796    601-800                        Yõldõz Technical University         NaN
# 797    601-800                           Yokohama City University         NaN
# 798    601-800                       Yokohama National University         NaN
# 799    601-800                                 Yuan Ze University         NaN
#
# [800 rows x 3 columns]

# %% [raw]
# new_sub.to_csv('mmj-submission-2.csv', encoding='latin1')

# %% [markdown]
# # How we did it

# %%
features = df.columns.values.tolist()[3:]
features.remove('female_male_ratio')
features.remove('international_students')

# %%
features
# Out:
# [u'teaching',
#  u'international',
#  u'research',
#  u'citations',
#  u'income',
#  u'total_score',
#  u'num_students',
#  u'student_staff_ratio',
#  u'year',
#  'percent_international_students',
#  'country_number']

# %%
df2 = df.copy()
train = df2[df2['year'] != 2016]
predict = df2.copy()[df2['year'] == 2016]
train = train.copy()
train.dropna(inplace=True)
predict = predict.copy()
predict = predict.drop('total_score', axis=1)

# %%
# predict.dropna(inplace=True)
predict.fillna(0, inplace=True)
features.remove('total_score')

# %%
X_train = train[features]
X = predict[features]
y_train = train['total_score']

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.99954040385548926

# %%
lasso = linear_model.LassoCV(cv=5)
m2 = lasso.fit(X_train, y_train)
print m2.score(X_train, y_train)
l_predict = m2.predict(X)
l_predict = pd.DataFrame(l_predict, columns=['lscores'])
# Out:
# 0.999474385802

# %%
from sklearn.cross_validation import cross_val_predict, cross_val_score
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
cross_val_score(linear_model.Ridge(), X_train, y_train, cv=5)
# Out:
# array([ 0.99753372,  0.99972069,  0.99979045,  0.9998776 ,  0.99939682])

# %%
r = linear_model.RidgeCV(cv=5)
m3 = r.fit(X_train, y_train)
print m3.score(X_train, y_train)
r_predict = m3.predict(X)
r_predict = pd.DataFrame(r_predict, columns=['rscores'])
# Out:
# 0.99954040074

# %%
predicted = model.predict(X)
predicted = pd.DataFrame(predicted, columns=['scores'])

# %%
predict = predict.reset_index(drop=True)

# %%
predictions = pd.concat([predict, predicted, r_predict, l_predict], axis=1)

# %%
check = predictions[['university_name', 'scores', 'rscores', 'lscores']]

# %%
feat_co = pd.DataFrame([features, model.coef_.tolist(), m3.coef_.tolist(), m2.coef_.tolist()],\
                       index=['features', 'coef','ridge','lasso']).T

# %%
m3.alpha_
# Out:
# 10.0

# %%
m2.alpha_
# Out:
# 0.35332992104073491

# %%
feat_co
# Out:
#                          features         coef        ridge        lasso
# 0                        teaching     0.299177     0.299166     0.298508
# 1                   international    0.0673121    0.0672952    0.0684345
# 2                        research     0.300598     0.300603     0.301986
# 3                       citations     0.304878     0.304853     0.301037
# 4                          income    0.0253693    0.0253665    0.0239791
# 5                    num_students  1.05242e-06  1.04876e-06 -8.37723e-07
# 6             student_staff_ratio -0.000623499 -0.000628185            0
# 7                            year     -0.06029    -0.059822           -0
# 8  percent_international_students   0.00631768   0.00634545            0
# 9                  country_number   0.00689968   0.00689085            0

# %%
feat_co[['features', 'ridge']]
# Out:
#                          features        ridge
# 0                        teaching     0.299166
# 1                   international    0.0672952
# 2                        research     0.300603
# 3                       citations     0.304853
# 4                          income    0.0253665
# 5                    num_students  1.04876e-06
# 6             student_staff_ratio -0.000628185
# 7                            year    -0.059822
# 8  percent_international_students   0.00634545
# 9                  country_number   0.00689085

# %%
check.sort_values(by='scores', ascending=False)
# Out:
#                                        university_name     scores    rscores  \
# 0                   California Institute of Technology  95.103664  95.104229
# 1                                 University of Oxford  93.953515  93.953870
# 2                                  Stanford University  93.720467  93.720756
# 3                              University of Cambridge  92.596340  92.596815
# 4                Massachusetts Institute of Technology  91.844142  91.844535
# 5                                   Harvard University  91.493438  91.493941
# 6                                 Princeton University  89.918154  89.918683
# 7                              Imperial College London  88.947443  88.948360
# 8    ETH Zurich Ð Swiss Federal Institute of Techno...  88.024165  88.024798
# 9                                University of Chicago  87.833091  87.833692
# 10                            Johns Hopkins University  87.516399  87.516929
# 11                                     Yale University  87.247515  87.248140
# 12                  University of California, Berkeley  87.118501  87.118888
# 13                           University College London  86.919635  86.920575
# 15               University of California, Los Angeles  85.756535  85.757052
# 14                                 Columbia University  85.243438  85.244155
# 16                          University of Pennsylvania  85.185758  85.186589
# 17                                  Cornell University  83.893353  83.894011
# 18                               University of Toronto  83.699255  83.699490
# 19                                     Duke University  82.606879  82.607409
# 21                          Carnegie Mellon University  82.378181  82.379436
# 20                              University of Michigan  82.330047  82.330743
# 22    London School of Economics and Political Science  80.764374  80.764269
# 23                             University of Edinburgh  80.082009  80.082744
# 24                             Northwestern University  79.443151  79.443806
# 25                    National University of Singapore  78.863749  78.864632
# 26                               KingÕs College London  78.046467  78.047285
# 27                                Karolinska Institute  77.457200  77.457920
# 28                                          LMU Munich  77.222678  77.223163
# 29                                 New York University  77.165820  77.166701
# ..                                                 ...        ...        ...
# 723                          Ocean University of China  14.997884  15.001153
# 621  Birla Institute of Technology and Science, Pilani  14.955247  14.958341
# 738             Rio de Janeiro State University (UERJ)  14.879427  14.882597
# 629            California State University, Long Beach  14.794498  14.797826
# 619                        Belarusian State University  14.663615  14.666355
# 735       Pontifical Catholic University of Valparaso  14.656546  14.659398
# 794                                  Xidian University  14.568074  14.571481
# 796                        Yõldõz Technical University  14.550271  14.553378
# 703                 University of Marrakech Cadi Ayyad  14.527623  14.530046
# 759                         University of South Africa  14.516368  14.518734
# 666                       Federal University of Lavras  14.515387  14.518979
# 792                       West University of Timi_oara  14.376978  14.379841
# 653                                University of Dhaka  14.360125  14.362854
# 773                                   Tokai University  14.319799  14.323082
# 720              Northwestern Polytechnical University  14.306398  14.310081
# 783                          Universiti Teknologi MARA  14.298026  14.300787
# 715                     National University of Crdoba  14.251004  14.253346
# 678                               University of Ibadan  14.244649  14.247575
# 670                    Gda_sk University of Technology  14.176674  14.179753
# 656  University of Electronic Science and Technolog...  14.164273  14.167814
# 611                                  Andhra University  14.154408  14.157916
# 785           V.N. Karazin Kharkiv National University  14.070947  14.074164
# 727                            University of Pardubice  14.035546  14.038808
# 760                        Southern Federal University  14.010144  14.013430
# 681                                  I-Shou University  13.995217  13.998645
# 758                                  Sophia University  13.842325  13.845814
# 753                                   Showa University  13.793957  13.797636
# 623                             University of Braslia  13.586893  13.590038
# 659                        Federal University of Bahia  13.568438  13.571580
# 661                Federal University of Paran (UFPR)  13.410966  13.414398
#
#        lscores
# 0    95.196888
# 1    94.045323
# 2    93.882115
# 3    92.714998
# 4    91.901901
# 5    91.664599
# 6    90.082404
# 7    88.965638
# 8    88.120201
# 9    88.024637
# 10   87.620346
# 11   87.444011
# 12   87.297845
# 13   86.980075
# 15   85.922958
# 14   85.424876
# 16   85.340635
# 17   84.097786
# 18   83.853602
# 19   82.715036
# 21   82.464118
# 20   82.481575
# 22   81.160422
# 23   80.189409
# 24   79.601102
# 25   78.993384
# 26   78.163477
# 27   77.569029
# 28   77.302210
# 29   77.307628
# ..         ...
# 723  15.414167
# 621  15.263778
# 738  15.211756
# 629  15.305260
# 619  14.827911
# 735  14.952440
# 794  14.952215
# 796  14.901167
# 703  14.733615
# 759  14.643426
# 666  14.959962
# 792  14.572377
# 653  14.454243
# 773  14.784176
# 720  14.800748
# 783  14.394033
# 715  14.194126
# 678  14.396431
# 670  14.453740
# 656  14.653566
# 611  14.486732
# 785  14.086960
# 727  14.371594
# 760  14.310298
# 681  14.383362
# 758  14.361795
# 753  14.374576
# 623  13.932784
# 659  13.917666
# 661  13.811195
#
# [800 rows x 4 columns]

# %%
final = check.sort_values(by='scores', ascending=False)

# %%
mmj_submit = submit.merge(final)

# %%
mmj_submit.head()
# Out:
#   world_rank                        university_name  total_score     scores  \
# 0          1     California Institute of Technology          NaN  95.103664
# 1          2                   University of Oxford          NaN  93.953515
# 2          3                    Stanford University          NaN  93.720467
# 3          4                University of Cambridge          NaN  92.596340
# 4          5  Massachusetts Institute of Technology          NaN  91.844142
#
#      rscores    lscores
# 0  95.104229  95.196888
# 1  93.953870  94.045323
# 2  93.720756  93.882115
# 3  92.596815  92.714998
# 4  91.844535  91.901901

# %%
mmj_submit.drop(['total_score', 'scores', 'lscores'],axis=1, inplace=True)

# %%
mmj_submit
# Out:
#     world_rank                                    university_name    rscores
# 0            1                 California Institute of Technology  95.104229
# 1            2                               University of Oxford  93.953870
# 2            3                                Stanford University  93.720756
# 3            4                            University of Cambridge  92.596815
# 4            5              Massachusetts Institute of Technology  91.844535
# 5            6                                 Harvard University  91.493941
# 6            7                               Princeton University  89.918683
# 7            8                            Imperial College London  88.948360
# 8            9  ETH Zurich Ð Swiss Federal Institute of Techno...  88.024798
# 9           10                              University of Chicago  87.833692
# 10          11                           Johns Hopkins University  87.516929
# 11          12                                    Yale University  87.248140
# 12          13                 University of California, Berkeley  87.118888
# 13          14                          University College London  86.920575
# 14          15                                Columbia University  85.244155
# 15          16              University of California, Los Angeles  85.757052
# 16          17                         University of Pennsylvania  85.186589
# 17          18                                 Cornell University  83.894011
# 18          19                              University of Toronto  83.699490
# 19          20                                    Duke University  82.607409
# 20          21                             University of Michigan  82.330743
# 21          22                         Carnegie Mellon University  82.379436
# 22          23   London School of Economics and Political Science  80.764269
# 23          24                            University of Edinburgh  80.082744
# 24          25                            Northwestern University  79.443806
# 25          26                   National University of Singapore  78.864632
# 26          27                              KingÕs College London  78.047285
# 27          28                               Karolinska Institute  77.457920
# 28          29                                         LMU Munich  77.223163
# 29          30                                New York University  77.166701
# ..         ...                                                ...        ...
# 770    601-800                               University of Tehran  18.886255
# 771    601-800                     University of Texas at El Paso  18.670885
# 772    601-800                              Texas Tech University  22.546364
# 773    601-800                                   Tokai University  14.323082
# 774    601-800                               Tokushima University  20.446023
# 775    601-800  Tokyo University of Marine Science and Technology  17.397450
# 776    601-800                        Tokyo University of Science  22.475351
# 777    601-800                             Tomsk State University  22.644193
# 778    601-800                                 Tottori University  15.063733
# 779    601-800                 Toyohashi University of Technology  19.936732
# 780    601-800                     Universiti Kebangsaan Malaysia  18.299994
# 781    601-800                          Universiti Putra Malaysia  21.433493
# 782    601-800                          Universiti Sains Malaysia  20.863074
# 783    601-800                          Universiti Teknologi MARA  14.300787
# 784    601-800                            Ural Federal University  17.820629
# 785    601-800           V.N. Karazin Kharkiv National University  14.074164
# 786    601-800                                 University of Vigo  21.354137
# 787    601-800                                 Vilnius University  21.600945
# 788    601-800                    Warsaw University of Technology  23.304171
# 789    601-800                                  Waseda University  23.145602
# 790    601-800                         University of West Bohemia  19.265549
# 791    601-800                  University of the West of England  22.853383
# 792    601-800                       West University of Timi_oara  14.379841
# 793    601-800                          University of Westminster  21.427220
# 794    601-800                                  Xidian University  14.571481
# 795    601-800                                Yeungnam University  19.310508
# 796    601-800                        Yõldõz Technical University  14.553378
# 797    601-800                           Yokohama City University  23.226907
# 798    601-800                       Yokohama National University  17.403209
# 799    601-800                                 Yuan Ze University  21.175714
#
# [800 rows x 3 columns]

# %% [raw]
# mmj_submit.to_csv('mike-max-joce-ranking-submission.csv', encoding='latin1')

# %%
mmj_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 0 to 799
# Data columns (total 3 columns):
# world_rank         800 non-null object
# university_name    800 non-null object
# rscores            800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 25.0+ KB

# %%
submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
# world_rank         800 non-null object
# university_name    800 non-null object
# total_score        0 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 18.8+ KB

# %%
mmj_submit
# Out:
#     world_rank                                    university_name    rscores
# 0            1                 California Institute of Technology  95.104229
# 1            2                               University of Oxford  93.953870
# 2            3                                Stanford University  93.720756
# 3            4                            University of Cambridge  92.596815
# 4            5              Massachusetts Institute of Technology  91.844535
# 5            6                                 Harvard University  91.493941
# 6            7                               Princeton University  89.918683
# 7            8                            Imperial College London  88.948360
# 8            9  ETH Zurich Ð Swiss Federal Institute of Techno...  88.024798
# 9           10                              University of Chicago  87.833692
# 10          11                           Johns Hopkins University  87.516929
# 11          12                                    Yale University  87.248140
# 12          13                 University of California, Berkeley  87.118888
# 13          14                          University College London  86.920575
# 14          15                                Columbia University  85.244155
# 15          16              University of California, Los Angeles  85.757052
# 16          17                         University of Pennsylvania  85.186589
# 17          18                                 Cornell University  83.894011
# 18          19                              University of Toronto  83.699490
# 19          20                                    Duke University  82.607409
# 20          21                             University of Michigan  82.330743
# 21          22                         Carnegie Mellon University  82.379436
# 22          23   London School of Economics and Political Science  80.764269
# 23          24                            University of Edinburgh  80.082744
# 24          25                            Northwestern University  79.443806
# 25          26                   National University of Singapore  78.864632
# 26          27                              KingÕs College London  78.047285
# 27          28                               Karolinska Institute  77.457920
# 28          29                                         LMU Munich  77.223163
# 29          30                                New York University  77.166701
# ..         ...                                                ...        ...
# 770    601-800                               University of Tehran  18.886255
# 771    601-800                     University of Texas at El Paso  18.670885
# 772    601-800                              Texas Tech University  22.546364
# 773    601-800                                   Tokai University  14.323082
# 774    601-800                               Tokushima University  20.446023
# 775    601-800  Tokyo University of Marine Science and Technology  17.397450
# 776    601-800                        Tokyo University of Science  22.475351
# 777    601-800                             Tomsk State University  22.644193
# 778    601-800                                 Tottori University  15.063733
# 779    601-800                 Toyohashi University of Technology  19.936732
# 780    601-800                     Universiti Kebangsaan Malaysia  18.299994
# 781    601-800                          Universiti Putra Malaysia  21.433493
# 782    601-800                          Universiti Sains Malaysia  20.863074
# 783    601-800                          Universiti Teknologi MARA  14.300787
# 784    601-800                            Ural Federal University  17.820629
# 785    601-800           V.N. Karazin Kharkiv National University  14.074164
# 786    601-800                                 University of Vigo  21.354137
# 787    601-800                                 Vilnius University  21.600945
# 788    601-800                    Warsaw University of Technology  23.304171
# 789    601-800                                  Waseda University  23.145602
# 790    601-800                         University of West Bohemia  19.265549
# 791    601-800                  University of the West of England  22.853383
# 792    601-800                       West University of Timi_oara  14.379841
# 793    601-800                          University of Westminster  21.427220
# 794    601-800                                  Xidian University  14.571481
# 795    601-800                                Yeungnam University  19.310508
# 796    601-800                        Yõldõz Technical University  14.553378
# 797    601-800                           Yokohama City University  23.226907
# 798    601-800                       Yokohama National University  17.403209
# 799    601-800                                 Yuan Ze University  21.175714
#
# [800 rows x 3 columns]
